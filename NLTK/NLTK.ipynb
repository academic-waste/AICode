# %% [markdown]
# # NLP
# ### 什么是自然语言处理
# - 计算机科学、人工智能和语言学领域的一个分支，它致力于使计算机能够理解、解释和生成人类语言。
# ![image-2.png](attachment:image-2.png)
# ### 发展史
# ![image-11.png](attachment:image-11.png)
#
# - 1950年代
#     - 1950年代中期：艾伦·图灵提出了图灵测试，这是判断机器是否具有智能的一个标准，也为后来的自然语言处理研究奠定了基础。
# - 1970年代
#     - 1970年代：语法和规则为基础的，能够处理更复杂的语言现象，但它们的通用性和鲁棒性有限。
#
# - 1990年代
#     - 1990年代：随着互联网的兴起，可用于NLP研究的数据量大幅增加，统计方法开始占据主导地位。
#     - 1993：第一个支持向量机（SVM）被提出，这是一种强大的分类算法，后来被广泛应用于NLP任务中。
# - 2000年代
#     - 2001：谷歌推出了其网络搜索引擎，使用了链接分析和词频-逆文档频率（TF-IDF）等NLP技术。
#     - 2006：深度学习的概念被重新引入，随着计算能力的提升和大数据的出现，深度神经网络开始在NLP中扮演越来越重要的角色。
# - 2010年代
#     - 2010年代：随着深度学习技术的发展，如循环神经网络（RNN）和卷积神经网络（CNN），NLP领域取得了显著进展。
#     - 2013：Word2Vec模型的提出，使得单词可以被表示为连续的向量，这在很多NLP任务中都取得了很好的效果。
#     - 2014：序列到序列（Seq2Seq）模型的提出，为机器翻译等序列生成任务提供了新的解决方案。
#     - 2018：BERT（Bidirectional Encoder Representations from Transformers）模型的提出，它使用预训练的Transformer模型来创建深度的语言表示，极大地推动了NLP的发展。
# - 2020年代
#     - 2020年代：NLP领域继续快速发展，预训练模型如GPT-3等具有数十亿参数的模型被开发出来，它们能够在没有明确监督的情况下生成高质量的文本。
#
# - NLP 的目标是让计算机能够处理和分析自然语言数据，以便更好地理解和响应人类的语言
# - NLP有两个子领域 NLG 和 NLU ，分别代表自然语言生成（Natural Language Generation）和自然语言理解（Natural Language Understanding）
# ![image-4.png](attachment:image-4.png)
# ### 应用
# - Sentimental Analysis
# - chatbot
# - Speech recognition
# - Machine Translation
# ### 如何工作
# - 标记化- 将输入序列分割为单词、短语、句子等（称为标记）的过程
# - 词干提取- 删除和替换后缀以获得称为词干的词根形式的过程
# - 词形还原- 此过程使用词汇或形态分析并返回称为词元的单词的字典形式
# - 命名实体识别 -检测命名实体（例如人名、公司名称、数量或位置等）的过程。
# - 分块 -将不同的信息片段或标记放在一起并将它们组合成更大的片段（称为组块）的过程
# - 停用词删除
#
# ### NLP深度学习技术
# ![image-10.png](attachment:image-10.png)
#
# ### NLP框架
# - NLTK    最早用 Python 编写的 NLP 库之一 . 提供易于使用的接口。它还提供了一套用于分类、标记、词干、解析和语义推理的文本处理库
# - spaCy   最通用的开源 NLP 库之一。它支持超过 66 种语言。spaCy 还提供预训练的词向量并实现许多流行的模型
# - TensorFlow Pytorch     可以更轻松地创建具有自动微分等功能的模型。这些库是开发 NLP 模型最常用的工具
# - Hugging Face            提供超过 135 个最先进模型的开源实现和权重。该存储库可以轻松定制和训练模型
#
# ## 相关任务
# ### 语料库(Corpus)
#     - 语料库（Corpus）是一个用于研究的大型文本集合。 通常包含大量的文本数据，这些数据可以是书籍、文章、网页、对话记录等，涵盖了广泛的主题、风格和语言使用场景。
#     - 主要用于语言模型训练，词性标注和语法分析
# ###  词库(Lexicon)
#     - 词汇表或词典。它是一个包含特定语言中所有单词或术语的列表。对于不同行业也不同的词库
# ### 标记(Token)
#     - Token是指从文本中分离出的基本单元，通常是单词、标点符号、数字或任何其他有意义的字符序列。文本的标记化（Tokenization）过程就是将文本分解成这些单元的过程。 例如“Hello, how are you?” 可以被分词为 Hello   ,  how  are you ?
# ### 停止词(Stop Words)
#     - Stop Words通常是指在文本中出现频次较高，但对文本内容意义无关的词。例如 the is are in on at and of to for 等
#     - 我们也可以自定义不同的停止词
#     - 停止词在任务中都会被移除，以便于提升计算效率。
# ### 词干提取(stemming)
#     - Stemming一般发生在文本预处理阶段，用于去除单次的词尾变化例如时态(ing,ed)，单复数(s, es), ly
#     - 其目的用于减少词汇多样性， 提高计算，检索性能
#     - 可能在某些情况下丢失单词的一些语义信息
# ### 词性标注Part-of-speech (POS) Tagging
#     - 磁性标注用于将文本中的单次分配一个词性(名词 动词 形容词 副词)
#     - 词性标注的正确性直接影响到后续处理的质量
#     例如，英文句子 “The cat sits on the mat” 可以被词性标注为：
#
#     The → 冠词 (Determiner)
#     cat → 名词 (Noun)
#     sits → 动词 (Verb)
#     on → 介词 (Preposition)
#     the → 冠词 (Determiner)
#     mat → 名词 (Noun)
#
# ### 分块 chunking
#     - 将文本分割成更大的片段，这些片段通常是具有语法意义的短语或从句。介于词性标注(POS Tagging)和完全语法分析(Full Syntax Parsing)之间
#     - 其目的是将词语按照语法组成有意义的单元。如名词短语，动词短语，介词短语等。有助于将原始文本转换为更结构化的格式，从而便于进一步的语义分析。
#     - 分块通常是通过定义一系列规则来实现的，这些规则基于词性标签序列。例如一个名词短语可以由一个或多个形容词后跟上名词组成
#     - 例如 The white cat sit on the table
#         将会分块为[The white cat]名词短语  sit [on the table]介词短语
#
# ### 命名实体识别(NER - Named Entity Recognition)
#     - 识别文本中具有特定意义的实体，并将它们分类到预定义的类别中，如人名、地点、组织、时间、金额等
#     - 通过识别文本中的命名实体，可以更深入地理解文本的内容和上下文
#     - 例如：" Greg went to  Southeast University and XunWu lake last week"
#
#             Greg -- >人名
#             Southeast University -->地名
#             XunWu lake --> 地名
#     - 命名实体识别可以通过基于规则的方法实现，也可以通过机器学习方法，如条件随机场（CRF）、深度学习模型（如双向LSTM、BERT）等。这些方法通常需要大量的标注数据进行训练，以便模型能够学习如何从文本中识别和分类命名实体。
#
# ### 词性还原(Lemmatization)
#     - 将单词的变形形式还原为其基本形式
#     - 例如running 还原为run
# ### 词性还原 vs 词干提取
#     - 都是用于将单词还原到其基本形式的技术的术语
#                         词性还原                                           词干提取
#        目的       将单词还原到其字典形式                               通过去除单词的后缀（如-s，-ed，-ing等）来简化单词形式
#        方式       通常涉及对单词的形态学分析，包括词性和词形变化规则        使用一组固定的规则来剪切单词的后缀
#        优势       通常提供更准确的词形还原,保证语意完整                   速度快，实现简单，不需要大量的语言资源。
#        劣势       过程更复杂，计算成本更高，需要访问词典和词性标注信息       可能无法正确处理所有单词，并丢失语义
# ### 文本特征提取
#
# - 为什么要做特征提取
#     - 在机器计算过程中一般输入输出都是固定长度，而文本内容却都是非结构化，此时我们需要将文本数值化 尤其是数值向量
#     - 通过特征提取有助于简化数据，提高模型训练效率
#     - 提高可解释性。 通过特征提取，我们更难容易理解模型的整个决策过程，从而提供模型的可解释性
# - 词袋模型 bag of words
#     - ag-of-Words 计算每个单词在文档中出现的次数。
#     - 不考虑文本中词与词之间的上下文关系，仅仅只考虑所有词出现的频率）
#    ![image-6.png](attachment:image-6.png)
#     - 词袋模型在处理文本分类和文本相似度上效率很高。计算向量距离
#     - 词袋模型需要一个很大的词库
#     - 文本相似度比较准确度不高
#
#
# - TF-IDF Term Frequency-Inverse Document Frequency）是一种用于评估一个单词对于一个文档集合中一个文档的重要性的统计方法。它结合了两个指标： ）。
#     - TF - 词频（Term Frequency，TF）
#         - 单词是否对当前文档重要？  TF =  词t在文档中出现的次数 / 文档中的单词总数
#
#         ![image-7.png](attachment:image-7.png)
#
#
#     - IDF - 逆文档频率（Inverse Document Frequency
#         - 单词在整个文档集合中的独特性?   IDF = log(文档总数/出现该单词的文档树)
#         ![image-8.png](attachment语义信息的捕捉
#         - :image-8.png)
#
#     - TF-IDF = TF * IDF
#     ![image-9.png](attachment:image-9.png)
#
# - 词向量
#     - 将单词映射到高维空间中的稠密向量。这些向量能够捕捉到单词的语义和上下文信息，使得在数学上可以计算单词之间的相似性和关联性
#     - 词向量关注单词的语义和上下文信息，适用于需要理解单词含义和关系的任务
#     - 词向量通常需要大量的文本数据进行预训练 Word2Vec
#
# - 总结
#     - 语义信息的捕捉。 词向量能够捕捉到单词的语义信息，这意味着语义相似的单词在向量空间中彼此靠近
#     - 上下文依赖。 词向量能够根据单词的上下文变化，从而为同一个单词提供不同的向量表示
#     - 词向量支持向量运算，这意味着可以通过向量加法和减法来探索词之间的关系
#     -
#
#
#
#
# ## NLTK(Natural Language Toolkit)
#     - 一个python自然语言处理库，用于处理和分析文本数据
#     - NLTK包含了大量的语料库和预训练的模型，可以方便地用于NLP任务的演示和开发。
#     - 提供了一系列的模块和函数，可以用来处理和分析文本数据
#     - 被广泛用于学术研究和教学
#     -

# %% [markdown]
# ### 安装nltk
#
# =
# ![image.png](attachment:image.png)
#
#
#
# - corpora  这个文件夹包含NLTK处理语料库的代码
# - tokenize 这个文件夹包含NLTK的文本分词和分句代码
# - tag      这个文件夹包含NLTK的词性标注和命名实体识别代码
# - stemmer  文件夹通常包含用于词干提取和词形还原的模块和数据 PorterStemmer

# %%
pip install nltk

import nltk
nltk.download()

https://github.com/nltk/nltk

# %% [markdown]
# ### 语料库

# %%
# 加载语料库

from nltk.tokenize import sent_tokenize, PunktSentenceTokenizer
from nltk.corpus import state_union

# sample text
sample = state_union.raw("2005-GWBush.txt")

tok = sent_tokenize(sample)

for x in range(100):
    print(tok[x])
# Out:
# PRESIDENT GEORGE W. BUSH'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION
#
# February 2, 2005
#
#
# 9:10 P.M. EST
#
# THE PRESIDENT: Mr. Speaker, Vice President Cheney, members of Congress, fellow citizens:
#
# As a new Congress gathers, all of us in the elected branches of government share a great privilege: We've been placed in office by the votes of the people we serve.
# And tonight that is a privilege we share with newly-elected leaders of Afghanistan, the Palestinian Territories, Ukraine, and a free and sovereign Iraq.
# (Applause.)
# Two weeks ago, I stood on the steps of this Capitol and renewed the commitment of our nation to the guiding ideal of liberty for all.
# This evening I will set forth policies to advance that ideal at home and around the world.
# Tonight, with a healthy, growing economy, with more Americans going back to work, with our nation an active force for good in the world -- the state of our union is confident and strong.
# (Applause.)
# Our generation has been blessed -- by the expansion of opportunity, by advances in medicine, by the security purchased by our parents' sacrifice.
# Now, as we see a little gray in the mirror -- or a lot of gray -- (laughter) -- and we watch our children moving into adulthood, we ask the question: What will be the state of their union?
# Members of Congress, the choices we make together will answer that question.
# Over the next several months, on issue after issue, let us do what Americans have always done, and build a better world for our children and our grandchildren.
# (Applause.)
# First, we must be good stewards of this economy, and renew the great institutions on which millions of our fellow citizens rely.
# America's economy is the fastest growing of any major industrialized nation.
# In the past four years, we provided tax relief to every person who pays income taxes, overcome a recession, opened up new markets abroad, prosecuted corporate criminals, raised homeownership to its highest level in history, and in the last year alone, the United States has added 2.3 million new jobs.
# (Applause.)
# When action was needed, the Congress delivered -- and the nation is grateful.
# Now we must add to these achievements.
# By making our economy more flexible, more innovative, and more competitive, we will keep America the economic leader of the world.
# (Applause.)
# America's prosperity requires restraining the spending appetite of the federal government.
# I welcome the bipartisan enthusiasm for spending discipline.
# I will send you a budget that holds the growth of discretionary spending below inflation, makes tax relief permanent, and stays on track to cut the deficit in half by 2009.
# (Applause.)
# My budget substantially reduces or eliminates more than 150 government programs that are not getting results, or duplicate current efforts, or do not fulfill essential priorities.
# The principle here is clear: Taxpayer dollars must be spent wisely, or not at all.
# (Applause.)
# To make our economy stronger and more dynamic, we must prepare a rising generation to fill the jobs of the 21st century.
# Under the No Child Left Behind Act, standards are higher, test scores are on the rise, and we're closing the achievement gap for minority students.
# Now we must demand better results from our high schools, so every high school diploma is a ticket to success.
# We will help an additional 200,000 workers to get training for a better career, by reforming our job training system and strengthening America's community colleges.
# And we'll make it easier for Americans to afford a college education, by increasing the size of Pell Grants.
# (Applause.)
# To make our economy stronger and more competitive, America must reward, not punish, the efforts and dreams of entrepreneurs.
# Small business is the path of advancement, especially for women and minorities, so we must free small businesses from needless regulation and protect honest job-creators from junk lawsuits.
# (Applause.)
# Justice is distorted, and our economy is held back by irresponsible class-actions and frivolous asbestos claims -- and I urge Congress to pass legal reforms this year.
# (Applause.)
# To make our economy stronger and more productive, we must make health care more affordable, and give families greater access to good coverage -- (applause) -- and more control over their health decisions.
# (Applause.)
# I ask Congress to move forward on a comprehensive health care agenda with tax credits to help low-income workers buy insurance, a community health center in every poor country, improved information technology to prevent medical error and needless costs, association health plans for small businesses and their employees -- (applause) -- expanded health savings accounts -- (applause) -- and medical liability reform that will reduce health care costs and make sure patients have the doctors and care they need.
# (Applause.)
# To keep our economy growing, we also need reliable supplies of affordable, environmentally responsible energy.
# (Applause.)
# Nearly four years ago, I submitted a comprehensive energy strategy that encourages conservation, alternative sources, a modernized electricity grid, and more production here at home -- including safe, clean nuclear energy.
# (Applause.)
# My Clear Skies legislation will cut power plant pollution and improve the health of our citizens.
# (Applause.)
# And my budget provides strong funding for leading-edge technology -- from hydrogen-fueled cars, to clean coal, to renewable sources such as ethanol.
# (Applause.)
# Four years of debate is enough: I urge Congress to pass legislation that makes America more secure and less dependent on foreign energy.
# (Applause.)
# All these proposals are essential to expand this economy and add new jobs -- but they are just the beginning of our duty.
# To build the prosperity of future generations, we must update institutions that were created to meet the needs of an earlier time.
# Year after year, Americans are burdened by an archaic, incoherent federal tax code.
# I've appointed a bipartisan panel to examine the tax code from top to bottom.
# And when their recommendations are delivered, you and I will work together to give this nation a tax code that is pro-growth, easy to understand, and fair to all.
# (Applause.)
# America's immigration system is also outdated -- unsuited to the needs of our economy and to the values of our country.
# We should not be content with laws that punish hardworking people who want only to provide for their families, and deny businesses willing workers, and invite chaos at our border.
# It is time for an immigration policy that permits temporary guest workers to fill jobs Americans will not take, that rejects amnesty, that tells us who is entering and leaving our country, and that closes the border to drug dealers and terrorists.
# (Applause.)
# One of America's most important institutions -- a symbol of the trust between generations -- is also in need of wise and effective reform.
# Social Security was a great moral success of the 20th century, and we must honor its great purposes in this new century.
# (Applause.)
# The system, however, on its current path, is headed toward bankruptcy.
# And so we must join together to strengthen and save Social Security.
# (Applause.)
# Today, more than 45 million Americans receive Social Security benefits, and millions more are nearing retirement -- and for them the system is sound and fiscally strong.
# I have a message for every American who is 55 or older: Do not let anyone mislead you; for you, the Social Security system will not change in any way.
# (Applause.)
# For younger workers, the Social Security system has serious problems that will grow worse with time.
# Social Security was created decades ago, for a very different era.
# In those days, people did not live as long.
# Benefits were much lower than they are today.
# And a half-century ago, about sixteen workers paid into the system for each person drawing benefits.
# Our society has changed in ways the founders of Social Security could not have foreseen.
# In today's world, people are living longer and, therefore, drawing benefits longer.
# And those benefits are scheduled to rise dramatically over the next few decades.
# And instead of sixteen workers paying in for every beneficiary, right now it's only about three workers.
# And over the next few decades that number will fall to just two workers per beneficiary.
# With each passing year, fewer workers are paying ever-higher benefits to an ever-larger number of retirees.
# So here is the result: Thirteen years from now, in 2018, Social Security will be paying out more than it takes in.
# And every year afterward will bring a new shortfall, bigger than the year before.
# For example, in the year 2027, the government will somehow have to come up with an extra $200 billion to keep the system afloat -- and by 2033, the annual shortfall would be more than $300 billion.
# By the year 2042, the entire system would be exhausted and bankrupt.
# If steps are not taken to avert that outcome, the only solutions would be dramatically higher taxes, massive new borrowing, or sudden and severe cuts in Social Security benefits or other government programs.
# I recognize that 2018 and 2042 may seem a long way off.
# But those dates are not so distant, as any parent will tell you.
# If you have a five-year-old, you're already concerned about how you'll pay for college tuition 13 years down the road.
# If you've got children in their 20s, as some of us do, the idea of Social Security collapsing before they retire does not seem like a small matter.
# And it should not be a small matter to the United States Congress.
# (Applause.)
# You and I share a responsibility.
# We must pass reforms that solve the financial problems of Social Security once and for all.
# Fixing Social Security permanently will require an open, candid review of the options.
# Some have suggested limiting benefits for wealthy retirees.
# Former Congressman Tim Penny has raised the possibility of indexing benefits to prices rather than wages.
# During the 1990s, my predecessor, President Clinton, spoke of increasing the retirement age.
# Former Senator John Breaux suggested discouraging early collection of Social Security benefits.

# %% [markdown]
# ### 词库
#     - WordNet 是英语的词汇数据库，由普林斯顿创建的同义词词典，是 NLTK 语料库的一部分
#     - 可以一起使用 WordNet 和 NLTK 模块来查找单词含义，同义词，反义词

# %%
from nltk.corpus import wordnet
syns = wordnet.synsets("good") #查看nice的同义词
print(syns)
print(syns[3].definition()) # 解释意义
print(syns[3].examples()) 
print_seperator()
synonyms = []
antonyms = []
for w in syns:
    for l in w.lemmas():
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())
print(synonyms)
print(antonyms)
# Out:
# [Synset('good.n.01'), Synset('good.n.02'), Synset('good.n.03'), Synset('commodity.n.01'), Synset('good.a.01'), Synset('full.s.06'), Synset('good.a.03'), Synset('estimable.s.02'), Synset('beneficial.s.01'), Synset('good.s.06'), Synset('good.s.07'), Synset('adept.s.01'), Synset('good.s.09'), Synset('dear.s.02'), Synset('dependable.s.04'), Synset('good.s.12'), Synset('good.s.13'), Synset('effective.s.04'), Synset('good.s.15'), Synset('good.s.16'), Synset('good.s.17'), Synset('good.s.18'), Synset('good.s.19'), Synset('good.s.20'), Synset('good.s.21'), Synset('well.r.01'), Synset('thoroughly.r.02')]
# articles of commerce
# []
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 6
#       4 print(syns[3].definition()) # 解释意义
#       5 print(syns[3].examples())
# ----> 6 print_seperator()
#       7 synonyms = []
#       8 antonyms = []
#
# NameError: name 'print_seperator' is not defined

# %% [markdown]
# ### 标记

# %%
from nltk.tokenize import sent_tokenize, word_tokenize


comment = "The actor's act was impressive. i like his show!!. "

sent_token = sent_tokenize(comment)  # 将文本分割成句子。 基于符号进行标记
print(sent_token)
print('***********')
word_token = word_tokenize(comment) # 单词标记

print(word_token)

def print_seperator():
    print('********************************************')

# %% [markdown]
# ### 停用词

# %%
# 停用词
from nltk.corpus import stopwords #停用词

stop_words = set(stopwords.words('english'))# 英语中所有的停用词
#print(stop_words) 



def filtered_stop_words(str):
    
    tokens = word_tokenize(str)
    return [w for w in tokens if not w in stop_words]




str='This is a sample sentence, showing off the stop words filtration. '

filtered_words = filtered_stop_words(str) #停用词删掉后的token
print(filtered_words)

# 添加自定义停用词
manual_stop_words= {'This'}
manual_stop_words = manual_stop_words.union(stop_words)
filtered_words2 = [w for w in filtered_words if not w in manual_stop_words] #停用词删掉后的token

print(filtered_words2)
# Out:
# ['This', 'sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration', '.']
# ['sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration', '.']

# %% [markdown]
# ### 词干提取  词形还原

# %%
# 词干提取
# 词干的概念是一种规范化方法。 除涉及时态之外，许多词语的变体都具有相同的含义。
from nltk.stem import PorterStemmer
str = 'I am a pythoner, my daily work is to write python scripts, when i was pythoning, i can feel it is pythonly'
filtered_words = filtered_stop_words(str)
print(filtered_words)
#通过停止词过滤
ps = PorterStemmer()

# 词干提取
for w in filtered_words:
    print(ps.stem(w))

 
# 词性还原
from nltk.stem import WordNetLemmatizer
for w in filtered_words:
    lemm = WordNetLemmatizer()
    print(lemm.lemmatize(w))
   



# pos参数，对于一个单词存在多种词性(n adj v)可以通过pos参数指定
str1 = 'xiaoming is a good programer, his python skill is better than java skill,his defect is better than others'
filtered_words = filtered_stop_words(str1)

count=0
result=''
for w in filtered_words:
    lemm = WordNetLemmatizer()
    if w == 'better':
        if count == 0:
            w=lemm.lemmatize(w,pos='a') # 句子中第一个better他们把他还原成形容词 --> good
            count +=1
            result+=w+" "
        else:
            w=lemm.lemmatize(w,pos='n') #句子中第2个better他们把他还原成名词 --> better
            result+=w+" "
    else:
        lemm.lemmatize(w)
        result+=w+" "
print(result)
# Out:
# ['I', 'pythoner', ',', 'daily', 'work', 'write', 'python', 'scripts', ',', 'pythoning', ',', 'feel', 'pythonly']
# i
# python
# ,
# daili
# work
# write
# python
# script
# ,
# python
# ,
# feel
# pythonli
# I
# pythoner
# ,
# daily
# work
# write
# python
# script
# ,
# pythoning
# ,
# feel
# pythonly
# xiaoming good programer , python skill good java skill , defect better others

# %% [markdown]
# ### 词性标注Part-of-speech (POS) Tagging
#     - 可以为你做词性标注。 意思是把一个句子中的单词标注为名词，形容词，动词等。它也可以按照时态来标记，以及其他
#     POS tag list:
#
# - CC    coordinating conjunction 并列连词
# - CD    cardinal digit
# - DT    determiner
# - EX    existential there (like: "there is" ... think of it like "there exists")
# - FW    foreign word
# - IN    preposition/subordinating conjunction
# - JJ    adjective    'big' 形容词
# - JJR    adjective, comparative    'bigger' 形容词比较级
# - JJS    adjective, superlative    'biggest' 形容词最高级
# - LS    list marker    1)
# - MD    modal    could, will
# - NN    noun, singular 'desk' 单个形容词
# - NNS    noun plural    'desks' 形容词复数
# - - NNP    proper noun, singular    'Harrison'  人名、地名、组织名或其他专有名词
# - NNPS    proper noun, plural    'Americans' 人名、地名、组织名或其他专有名词复数
# - PDT    predeterminer    'all the kids'
# - POS    possessive ending    parent's
# - PRP    personal pronoun    I, he, she
# - PRP    possessive pronoun    my, his, hers
# - RB    adverb    very, silently,
# - RBR    adverb, comparative    better
# - RBS    adverb, superlative    best
# - RP    particle    give up
# - TO    to    go 'to' the store.
# - UH    interjection    errrrrrrrm
# - VB    verb, base form    take
# - VBD    verb, past tense    took
# - VBG    verb, gerund/present participle    taking
# - VBN    verb, past participle    taken
# - VBP    verb, sing. present, non-3d    take
# - VBZ    verb, 3rd person sing. present    takes
# - WDT    wh-determiner    which
# - WP    wh-pronoun    who, what
# - WP   possessive wh-pronoun    whose
# - WRB    wh-abverb    where, when

# %%
# 标记器 PunktSentenceTokenizer 可以在你使用的任何文本上进行实际的训练
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import state_union #引入语料库
from nltk.tokenize import PunktSentenceTokenizer 

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")
custom_sent_tokenizer = PunktSentenceTokenizer(train_text)
tokenized = custom_sent_tokenizer.tokenize(sample_text)


def process_content():
    try:
        for i in tokenized[:1]:
            words = word_tokenize(i)
            tagged = nltk.pos_tag(words) # 打标
            print(tagged)

    except Exception as e:
        print(str(e))


process_content()

# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W.', 'NNP'), ('BUSH', 'NNP'), ("'S", 'POS'), ('ADDRESS', 'NNP'), ('BEFORE', 'NNP'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'NNP'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'NNP'), ('THE', 'NNP'), ('UNION', 'NNP'), ('January', 'NNP'), ('31', 'CD'), (',', ','), ('2006', 'CD'), ('THE', 'DT'), ('PRESIDENT', 'NNP'), (':', ':'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('.', '.')] [('Mr.', 'NNP'), ('Speaker', 'NNP'), (',', ','), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), (',', ','), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), (',', ','), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NNS'), (',', ','), ('distinguished', 'VBD'), ('guests', 'NNS'), (',', ','), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), (':', ':'), ('Today', 'NN'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), (',', ','), ('graceful', 'JJ'), (',', ','), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBN'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('.', '.')] [('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'NN'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'RB'), ('ago', 'RB'), (',', ','), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'NN'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('.', '.')] [('(', 'NN'), ('Applause', 'NNP'), ('.', '.'), (')', ':')] [('President', 'NNP'), ('George', 'NNP'), ('W.', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), (',', ','), ('Tuesday', 'NNP'), (',', ','), ('Jan', 'NNP'), ('.', '.')]
# Out:
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W.', 'NNP'), ('BUSH', 'NNP'), ("'S", 'POS'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('January', 'NNP'), ('31', 'CD'), (',', ','), ('2006', 'CD'), ('THE', 'NNP'), ('PRESIDENT', 'NNP'), (':', ':'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('.', '.')]

# %% [markdown]
# #### 分块(Chunk)
#     - 块的主要目标之一是将所谓的“名词短语”分组。 这些是包含一个名词的一个或多个单词的短语，可能是一些描述性词语，也可能是一个动词，也可能是一个副词
#     - 可以通过正则表达式结合词性标签
#     +  1个或多个
#     ?  0或1 个
#     *  0个或多个
#     . 任意字符

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize("Greg went to  Southeast University and XuanWU lake last week")


def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words) # 打标
            '''
            <NNP.?>*：零个或一个任何时态的副词，后面是：

            <VB.?>*：零个或一个任何时态的动词，后面是：

            <NNP>+：表示一个或多个专有名词，后面是：

            <NN>?：零个或一个名词单数。
            
            '''
            chunk_gram = r"""Chunk: {<NNP.?>*<VBD.?>*<NNP>+<NN>?}""" # 
            chunk_parser = nltk.RegexpParser(chunk_gram)
            chunked = chunk_parser.parse(tagged)
            chunked.draw()     
            for subtree in chunked.subtrees(filter=lambda t: t.label() == 'Chunk'):
                print(subtree)
    except Exception as e:
        print(str(e))



process_content()
# Out:
# (Chunk Greg/NNP)
# (Chunk Southeast/NNP University/NNP)
# (Chunk XuanWU/NNP)

# %% [markdown]
# #### 添加缝隙(chunking)
#     - 添加缝隙与分块很像，它基本上是一种从块中删除块的方法。 你从块中删除的块就是你的缝隙
#     - }{ 的方式添加删除内容

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize("Greg went to  Southeast University and XuanWU lake last week")


def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words) # 打标
            '''
            <RB.?>*：零个或一个任何时态的副词，后面是：

            <VB.?>*：零个或一个任何时态的动词，后面是：

            <NNP>+：表示一个或多个专有名词，后面是：

            <NN>?：零个或一个名词单数。
            
            '''
            #chunk_gram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}""" # 
            chunk_gram = r"""Chunk: {<.*>+}
                                    }<VB.?|IN|DT|TO>+{""" # 从缝隙中删除一个或多个动词，介词，限定词或to这个词
            chunk_parser = nltk.RegexpParser(chunk_gram)
            chunked = chunk_parser.parse(tagged)
            #chunked.draw()     
            for subtree in chunked.subtrees(filter=lambda t: t.label() == 'Chunk'):
                print(subtree)
    except Exception as e:
        print(str(e))



process_content()
# Out:
# (Chunk Greg/NNP)
# (Chunk Southeast/NNP University/NNP and/CC XuanWU/NNP)
# (Chunk last/JJ week/NN)

# %% [markdown]
# #### 命名实体识别
#     - 让机器立即能够拉出“实体”，例如人物，地点，事物，位置，货币等等

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize("Greg went to Peking University and XuanWu Lake last week ")

def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            namedEnt = nltk.ne_chunk(tagged, binary=False)
            # namedEnt.draw()
            print(namedEnt)
    except Exception as e:
        print(str(e))


process_content()
# Out:
# (S
#   (GPE Greg/NNP)
#   went/VBD
#   to/TO
#   (ORGANIZATION Peking/NNP University/NNP)
#   and/CC
#   (ORGANIZATION XuanWu/NNP Lake/NNP)
#   last/JJ
#   week/NN)

# %% [markdown]
# #### BOW

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from nltk import sent_tokenize
#vectorizer = CountVectorizer() 
vectorizer = TfidfVectorizer() 

paragraph = """The fox jumps over the lazy dog. Dog and fox are lazy"""
corpus = sent_tokenize(paragraph)
X = vectorizer.fit_transform(corpus) 

feature_names = vectorizer.get_feature_names_out() 

X_array = X.toarray() 

print ( "唯一单词列表: \n" , feature_names) 
print ( "词袋矩阵：\n",X_array)
# Out:
# 唯一单词列表:
#  ['and' 'are' 'dog' 'fox' 'jumps' 'lazy' 'over' 'the']
# 词袋矩阵：
#  [[0.         0.         0.25948224 0.25948224 0.36469323 0.25948224
#   0.36469323 0.72938646]
#  [0.53309782 0.53309782 0.37930349 0.37930349 0.         0.37930349
#   0.         0.        ]]

# %% [markdown]
# #### TF-IDF模型

# %%
import heapq
import numpy as np
import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer
from  nltk.corpus import stopwords

# stop word
stop_words = set(stopwords.words('english'))
manual_stop_words= {'applause'}
manual_stop_words=manual_stop_words.union(stop_words)

speech = state_union.raw("2005-GWBush.txt")
sentence = sent_tokenize(speech)

for i in range(len(sentence)):
    sentence[i]= sentence[i].lower() #转小写 
    sentence[i]= re.sub(r'\W',' ',sentence[i])
    sentence[i]= re.sub(r'\s',' ',sentence[i])


word_count={}



# 计数
for data in sentence:
    words = word_tokenize(data)
    words = [w for w in words if w not in manual_stop_words] #过滤掉无效的停止词
    for word in words:
        if word not in word_count.keys():
            word_count[word]=1
        else:
            word_count[word] +=1

# 频次最高的单词
freq_words = heapq.nlargest(100, word_count,key =word_count.get )
#for fw in freq_words:
#    print(fw,word_count[fw] )

print_seperator()
# TF-IDF  
# TD = numbers of word in current doc/total words in doc
# IDF = log(total number of docs/number of docs which contains the word)

word_idfs={}

# 计算IDF
for fw in freq_words: #遍历频次最高的单词
    doc_count = 0 # 单词出现在文档中的次数
    for sent in sentence: #遍历每个句子
        if fw in word_tokenize(sent):# 判断单词是否在句子当中。 这里每个句子我们当做一个文档doc
            doc_count+=1
    word_idfs[fw]=np.log(len(sentence) / doc_count+1)

print(word_idfs)

# 计算TF 

word_tfs={}
for fw in freq_words:
    doc_tf=[]
    for sent in sentence:
        frequency = 0
        words = word_tokenize(sent)
        words = [w for w in words if w not in manual_stop_words] 
        for w in words:
            if w == fw:
                frequency+=1
        tf_word_value= frequency/len(word_tokenize(sent))
        doc_tf.append(tf_word_value)
    word_tfs[fw] = doc_tf

print(word_tfs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 43
#      39 freq_words = heapq.nlargest(100, word_count,key =word_count.get )
#      40 #for fw in freq_words:
#      41 #    print(fw,word_count[fw] )
# ---> 43 print_seperator()
#      44 # TF-IDF
#      45 # TD = numbers of word in current doc/total words in doc
#      46 # IDF = log(total number of docs/number of docs which contains the word)
#      48 word_idfs={}
#
# NameError: name 'print_seperator' is not defined

# %% [markdown]
# ### word2vec

# %%
import heapq
import numpy as np
import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer
from  nltk.corpus import stopwords

 
speech = '''
The Benefits of Reading.Reading is a vital skill that offers numerous benefits. It expands our knowledge and understanding of the world. Through books, we can explore different cultures, gain insights into historical events, and learn about various subjects. Reading also enhances our vocabulary and language skills, improving our communication abilities.

In addition to these cognitive benefits, reading has a profound impact on our emotional well-being. It allows us to escape into different worlds, experiencing a wide range of emotions through the characters and stories we encounter. This escapism can be a valuable form of relaxation and stress relief.

Moreover, reading fosters creativity and imagination. As we immerse ourselves in the narratives, our minds create vivid images and scenarios, stimulating our creative thinking. This imaginative exercise can have a positive influence on our personal and professional lives, encouraging innovation and problem-solving.

In conclusion, reading is not just a hobby but an essential activity that enriches our lives in countless ways. It is a tool for personal growth, emotional regulation, and intellectual development. Therefore, we should make it a priority to read regularly and encourage others to do the same.
'''
sentences = sent_tokenize(speech)

for i in range(len(sentence)):
    # sentences[i]= sentence[i].lower() #转小写 
    sentences[i]= re.sub(r'\W',' ',sentences[i])
    sentences[i]= re.sub(r'\s',' ',sentences[i])
    sentences[i] = filter_stop_words(sentences[i])
    
    
    
from gensim.models import Word2Vec

 
words = [word_tokenize(sent) for sent in sentences] 


model = Word2Vec(words,min_count=1,vector_size=300,window=10)

vector = model.wv['but']
print(vector)
#simi = model.wv.most_similar('2tt')
#print(simi)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import re
# ----> 4 import nltk
#       5 from nltk.tokenize import sent_tokenize, word_tokenize
#       6 from nltk.corpus import state_union
#
# ModuleNotFoundError: No module named 'nltk'

# %% [markdown]
# ### 情感分析

# %%
import json
from nltk.corpus import state_union
from nltk.tokenize import word_tokenize
import json
import os
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords #停用词
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
import numpy as np


from sklearn.metrics import accuracy_score
data_dir = '/users/zhuyang/nltk_data/corpora/state_union'
file_name = 'greg.json'


file_path = os.path.join(data_dir, file_name)

with open(file_path, 'r') as file:
    data = json.load(file)
    

reviews=[]
labels=[]

for item in data:
    review = item['review']
    label = item['rating']
    reviews.append(review)
    labels.append(label)


# 预处理数据
stop_words = set(stopwords.words('english'))
# 删除停用词
def filter_stop_words(review):
    words = word_tokenize(review)
    filtered_tokens = [token for token in words if token not in stop_words]
    return ' '.join(filtered_tokens)

filtered_reviews = [filter_stop_words(review ) for review in reviews]
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer 

# 词袋模型
#vector = CountVectorizer()
# 特征提取基于tf-idf
vector = TfidfVectorizer()


X = vector.fit_transform(filtered_reviews)
y = labels


# 划分数据
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.22, random_state=42)  

# 训练
from sklearn.naive_bayes import MultinomialNB #多项式贝叶斯
from sklearn.tree import DecisionTreeClassifier # 决策树
from sklearn.ensemble import RandomForestClassifier # 随机森林
from sklearn.svm import SVC
classifier = MultinomialNB() #0.72
#classifier = DecisionTreeClassifier()# 0.64
#classifier = RandomForestClassifier(n_estimators=20, random_state=42) #0.74
#classifier = SVC(kernel='linear', C=1.0, random_state=42) #0.76
classifier.fit(X_train,y_train)

#预测
y_pred = classifier.predict(X_test)

# 打印准确度
print(accuracy_score(y_test,y_pred))


# 找出预测错误的样本
incorrect_predictions = [(y_t, y_p) for y_t, y_p in zip(y_test, y_pred) if y_t != y_p]

correct_predictions = [(y_t, y_p) for y_t, y_p in zip(y_test, y_pred) if y_t == y_p]

# 打印预测错误的样本数量
print(f'错误预测: {len(incorrect_predictions)}')
print(f'总共预测: {len(y_pred)}')
 
'''    
for y_true, y_pred in correct_predictions:
    #print(f'True: {y_true}, Predicted: {y_pred}')
    print('-' * 50)
'''    


def predict_comment(comment):
    comment = filter_stop_words(comment)
    feature = vector.transform([comment])
    prediction = classifier.predict(feature)
    return prediction


print(predict_comment("suggest to add a extra function into the APP which allow me to check UP.TO.DATE TOTAL AMOUNT SMRT REBATES REDEEMED & THE AVAILABLE AMOUNT OF BALANCED SMRT REBATES LEFT FOR THE ANNUAL CAP OF $600 FROM MY SMRT VISA"))
# Out:
# 0.7283813747228381
# 错误预测: 245
# 总共预测: 902
# [1]

# %% [markdown]
# ### 利用nltk分析情感

# %%
import json
from nltk.corpus import state_union
from nltk.tokenize import word_tokenize
import json
import os
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords #停用词
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.metrics import classification_report
from nltk.sentiment import SentimentIntensityAnalyzer

from sklearn.metrics import accuracy_score
data_dir = '/users/zhuyang/nltk_data/corpora/state_union'
file_name = 'greg.json'


file_path = os.path.join(data_dir, file_name)

with open(file_path, 'r') as file:
    data = json.load(file)
    

reviews=[]
labels=[]

for item in data:
    review = item['review']
    label = item['rating']
    reviews.append(review)
    labels.append(label)


# 预处理数据
stop_words = set(stopwords.words('english'))
# 删除停用词
def filter_stop_words(review):
    words = word_tokenize(review)
    filtered_tokens = [token for token in words if token not in stop_words]
    return ' '.join(filtered_tokens)

filtered_reviews = [filter_stop_words(review ) for review in reviews]

sia = SentimentIntensityAnalyzer()
for i in range(len(filtered_reviews)):
    review = filtered_reviews[i]
    score = sia.polarity_scores(review)
    rate = labels[i]
    print(score,review,'label=',rate)
    
'''
pos 是积极情感的分数。
neg 是消极情感的分数。
neu 是中性情感的分数
compound 是一个综合分数，它表示文本的整体情感倾向。这个分数是一个介于 -1.0 和 1.0 之间的浮点数，其中：


compound = ((pos-neu)-(neg-neu))/(pos+neu-neg)

分数接近 1.0 表示文本具有非常积极的情感。
分数接近 0.0 表示文本是中性的，没有明显的积极或消极情感。
分数接近 -1.0 表示文本具有非常消极的情感。

'''
# Out:
# {'neg': 0.087, 'neu': 0.799, 'pos': 0.114, 'compound': -0.327} Out sudden without warning I tried use App , prompted upgrade . Then I , returned indicated phone compatible . Citibank learn LTA fiasco EZlink card issue . Citibank least sent notification account holders push mail via SMS warn well beforehand new upgrade APP requires Handphone OS least Andriod `` X '' one wants use . Sigh ! ! ! label= 1
# {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'compound': 0.7212} Downloaded app activated digital card Citi PremierMiles . The temporary cvv popped I didnt take notice . Subsequent attempts view temporary cvv led pop activate physical card instead . So see card number , expiry date cvv ! ! ! ! Messaged customer center said needed escalate relevant teams solve . Seems like bug . label= 1
# {'neg': 0.211, 'neu': 0.617, 'pos': 0.172, 'compound': -0.7368} -1 Stars . * * Stop telling user send email support . U Tell Your Support Team The Issue ! ! * * .. Will give negative star option . Now even phone keyboard also want monitor . Why Google Keyboard also allow ! ! ? ? Useless lousy banking apps SG ! Slow loading user friendly ! .. Not able use Developer Option enable ! Sometimes need enable Developer Option certain function phone . Citibank So Disappointed In You ! 😡 label= 1
# {'neg': 0.042, 'neu': 0.88, 'pos': 0.078, 'compound': 0.2598} The Citibank IT set-up deplorable . Functions app n't work . There Global Wallet unable process basic payee set-up even though nothing wrong receiving account 's information . The app keeps saying information invalid . Question : bother providing IT banking functions n't work ? I suspect IT team never ever tests app online banking functions launching service . Customers beware . label= 1
# {'neg': 0.043, 'neu': 0.909, 'pos': 0.048, 'compound': 0.0772} * * Update : app defaulted back personal acct payment last couple months . Everything seems good . * * I 'm citibank client many years , recently opened another acct ( joint ) . Now App default using new joint acct make payment instead staying old acct ( personal ) . It 's first time 've make restitutions amt wrongly deducted together embarrassing explanation partner . The privacy personal spendings also compromised . label= 5
# {'neg': 0.171, 'neu': 0.829, 'pos': 0.0, 'compound': -0.5423} The app forces u use default Samsung keyboard phone else able type anything . This bad experience keep switching keyboards . label= 1
# {'neg': 0.092, 'neu': 0.908, 'pos': 0.0, 'compound': -0.466} Generally intuitive . And also , forcing change back Samsung keyboard use app ? Why ca n't let use default Google keyboard ? Then I change default keyboard settings using app . Ridiculous design . Did one test ? label= 1
# {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'compound': 0.6966} The app crashing every past 2 months since I signed . I uninstall reinstall re-register every time . This time , I already uninstalled reinstalled still keeps crashing , I ca n't even enter password . Ca n't check statement , ca n't enquire . Tried facebook dm automated message asks use app ? ? ? ? ? Please advise , thank . label= 1
# {'neg': 0.242, 'neu': 0.726, 'pos': 0.032, 'compound': -0.9477} Updated 12 march 2024 . OMG .... still worst bank app years . I tried changing app pin gave error . Someone tried use cc ( gotten brand new card like week ago ) . Hotline still putting hold even I chose emergency option . Sucks . Old review : Worst banking app . Entered sms pin code sent mobile n't work . tried 3 times n I 'm locked . going charge late penalty since I 've idea much cc bill . label= 1
# {'neg': 0.183, 'neu': 0.769, 'pos': 0.048, 'compound': -0.7506} Suddenly stop login popup message said detected `` developer options '' phone . I checked phone enable . I gone enable disable developer options ensure phone really disabled . However , app still allows login . I stop using card 's fixed . Reply : My phone developer mode . I doubt app detected wrongly send wrong message also . label= 1
# {'neg': 0.042, 'neu': 0.846, 'pos': 0.111, 'compound': 0.5256} New review - Issue settled within day . Even I 've turn mentioned settings , issue log . Called & customer service officer helped rectify . Very efficient . Old review - Been really hassle log using app . It 's stated ca n't access app due detected 'USB debugging settings Developer Options enable . Emailed bank . This issue started months ago , I 've using app years problem . Pls help . label= 5
# {'neg': 0.137, 'neu': 0.863, 'pos': 0.0, 'compound': -0.6202} Not sure reason latency 's quite recent experience I . Additionally , chatbot feature working , never I ever gotten reply I still need go call centre route . Disappointed discrepancy Google search result Vs actually functionality fees waiver request chatbot label= 2
# {'neg': 0.121, 'neu': 0.785, 'pos': 0.094, 'compound': -0.1761} The latest update claims Google keyboard ( downloaded Google play store ) `` untrusted '' keyboard I ca n't type anything app , making completely useless . label= 1
# {'neg': 0.072, 'neu': 0.827, 'pos': 0.101, 'compound': -0.1967} Ever since app came customer service standard plummeted ! Very disappointed supposedly global giant . Now I ca n't even get call back month . Update : post call call back . Resolved issues . However issue Sept stayed unresolved . Was promised sms 's 7 days nothing ... previous months ! label= 1
# {'neg': 0.125, 'neu': 0.728, 'pos': 0.148, 'compound': 0.296} First time logging onto citibank app check credit card painful . Setup process issues like looping asking wan na use biometric ( fingerprint ) log . Accept still ask non stop . Navigating app slow laggy , menu needs load visit . UI hard make sense . Now try elderly throw phone . label= 1
# {'neg': 0.037, 'neu': 0.896, 'pos': 0.067, 'compound': 0.1431} Citi Mobile Token suddenly working upgrade popup . Unable get token unless I downloaded new application first , take longer time . Why NEED name contact number ? I need approve transaction , older application previously working fine suddenly stopped working new version available ? A simple tap approve become lot steps I need download install new version first . label= 1
# {'neg': 0.22, 'neu': 0.706, 'pos': 0.073, 'compound': -0.7351} Worst banking app among apps I used . Constantly using push notifications promote `` new '' services even already opted . Interface extremely laggy every step takes agonizing seconds load instant label= 1
# {'neg': 0.248, 'neu': 0.642, 'pos': 0.11, 'compound': -0.4588} No longer functional , app rejects using Microsoft SwiftKey keyboard , unable type app . Security protections gone absurd ... label= 1
# {'neg': 0.206, 'neu': 0.684, 'pos': 0.109, 'compound': -0.3125} Not friendly . Terrible auto phone . Going round circles . No proper channel ask simple question . Cant even request return call . label= 1
# {'neg': 0.22, 'neu': 0.61, 'pos': 0.171, 'compound': -0.296} Hi , l received 'Unable proceed ' message error opening app . Pls assist rectify error . My name Kenny Teo Kian Beng . Thanks label= 1
# {'neg': 0.091, 'neu': 0.678, 'pos': 0.231, 'compound': 0.7632} Ca n't login totally blind account status . Customer service unhelpful resolving issue leaving choice terminate account asap avoid another possibility unpaid outstanding charges ( $ 200 ) happened . Citibank customer service standard used high however dropped last three years unbelievable level . label= 1
# {'neg': 0.146, 'neu': 0.854, 'pos': 0.0, 'compound': -0.5334} Developer options yet app keep prompting auto close - Update : For Developer Options issue , turning Developer Options wo n't help . To resolve , simply enabled ( google ) scroll turn USB Debugging . label= 1
# {'neg': 0.29, 'neu': 0.659, 'pos': 0.051, 'compound': -0.8903} Can login open app despite phone developer mode . Stupid updates After 1-2 months , issues still n't solved . I need access app check outstanding amount . But I freaking ca n't . Can guys something ? Is crazy many banking app n't kind issues . label= 1
# {'neg': 0.324, 'neu': 0.499, 'pos': 0.177, 'compound': -0.8271} Worst bank app I ever seen . Worst support ever . Application expand collapse header graphics every time scroll . Payments n't work need . Concierge service impossible use . I think best option anyone looking Citibank bank - avoid unprofessional service . label= 1
# {'neg': 0.269, 'neu': 0.557, 'pos': 0.174, 'compound': -0.5106} Avoid using Citi services . They lost way enabling customers . Now making money applying random charges cc made difficult even reach customer care , customer left interest fines imposed left option paying value . Since 2 months struggling get get waiver annual fees , one replies charged . label= 1
# {'neg': 0.0, 'neu': 0.948, 'pos': 0.052, 'compound': 0.0258} I also issue logging , apps keep turned . Restarted phone however issue still exists . Not able see anything inside . Able provide email matter . label= 2
# {'neg': 0.289, 'neu': 0.615, 'pos': 0.096, 'compound': -0.8162} How update make worse . Developer mode useless function n't solve problem . And u ca n't even log auto offs without u anything , lack attention basics disappointing . Let alone slow glitchy ui . Does mean bills void ? 😂😂 label= 1
# {'neg': 0.109, 'neu': 0.891, 'pos': 0.0, 'compound': -0.2023} The app user-friendly . I looking priority pass key last 3 days still able find . I tried pay last bill , option available pay app . Once , app says I registered user . label= 1
# {'neg': 0.136, 'neu': 0.787, 'pos': 0.077, 'compound': -0.6124} Digital card fixed number transaction limits limits stated upfront explicitly . Have called talked customer service manager remove limit explain fraud possibility , citibank unable remove limit resolve issue . First time using Citibank , I disappointed Citibank service . Why offer digital card service first place option extend/override limit label= 1
# {'neg': 0.166, 'neu': 0.693, 'pos': 0.141, 'compound': -0.2732} Using 10 days getting prestige cc . Can safely conclude one worst banking mobile apps Singapore . Frozen screens generally slow , far cry experience provided mobile banking apps SG ( standard chartered example ) . Was expecting much better label= 1
# {'neg': 0.143, 'neu': 0.769, 'pos': 0.087, 'compound': -0.3987} bad app ! ! 1/ ca n't login , screen keeps loading several minutes fingerprint , mostly fails 2/ once-in-a-few days manage login , floods phone numerous outdated notifications 3/ result , almost never use app transaction verification . Citibank HK exactly app , somehow works perfectly & smoothly label= 1
# {'neg': 0.157, 'neu': 0.605, 'pos': 0.238, 'compound': 0.7036} Terrible ! My wife asks book car festivities wants pass $ 160 'credit card payment ' credit card , instead displayed credit font green color , Citi app shows debit `` - $ 160 '' ! A bank cant differentiate credit , debit , big NO ! banking industry ! Over span several years , 2nd 3rd time 'debit ' error happens Citi credit cards . Seems problem never fixed . label= 1
# {'neg': 0.188, 'neu': 0.812, 'pos': 0.0, 'compound': -0.6836} I unable login app since last week ! The icon keep circling yet n't changed ! I thought I might need update version newest ! What wrong ? ? ! ! label= 1
# {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'compound': 0.4692} Advertising messages via push notifications hidden transaction notifications ca n't turn ( lose advertising important transaction notifications ) Duplicate notifications message . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} I would give zero I could ! Ever time I carry authentication return back browser page , whole webpage hangs even . Same goes app even though I update app frequently . First world international bank third world technology customer service ! label= 1
# {'neg': 0.0, 'neu': 0.835, 'pos': 0.165, 'compound': 0.607} Buggy login process , API connection third party payment request made . The product manager needs replaced since looking feedback ( ) able fix basic login process despite several complaints customers . label= 3
# {'neg': 0.0, 'neu': 0.643, 'pos': 0.357, 'compound': 0.6124} Recent update cause Google board ( gboard ) work app .. please help . label= 1
# {'neg': 0.107, 'neu': 0.893, 'pos': 0.0, 'compound': -0.4767} This update even worse previous one . I totally unable log due false developer options thing . I ca n't even login internet internet mobile login disabled . I need switch banks soon label= 1
# {'neg': 0.078, 'neu': 0.922, 'pos': 0.0, 'compound': -0.296} Say developer option . Can enter app . Turn developer option still . Reinstall still . Called customer service asked paper copy till resolution issue . No paper copy received till date . label= 1
# {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'compound': 0.3818} Been trying download app ages avail ... disabled phone contact numbers . Now I ca n't even contact anybody even though I 'm holding credit card 30 years label= 1
# {'neg': 0.135, 'neu': 0.776, 'pos': 0.089, 'compound': -0.5978} Honestly one worst apps I 've ever used . It never works . I never log always forced uninstall reinstall . I ca n't use authentication cos I simply ca n't launch . The payment bills terrible ! After paying bill , 's indication paid ! I triple paid bill I n't know whether payment went ! ( note , reverse payment bank instead take 2 wks send cheque u ! ) label= 1
# {'neg': 0.336, 'neu': 0.634, 'pos': 0.03, 'compound': -0.969} I 've used banking apps intuitive citibank app horrible . Firstly , estatement button seems well hidden , extremely difficult find . Secondly hate point system , n't tell expiry date 60days expiry . The app n't link reward page , even reward page horrible . If multiple cards choose first card , cant go back second card . Login always hang . Bad ! label= 2
# {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.7333} Hotline asks us go app banking transactions services available ! I 'd like ask annual fee waiver 's option doesnt option phone service . This app functions bill viewer . That 's . Totally helpful consumers staff ! label= 1
# {'neg': 0.163, 'neu': 0.774, 'pos': 0.063, 'compound': -0.8067} Very bad , many times I ca n't even log . Always show log error . Even times I log , lot info ca n't seen . It shows recent transactions I actually I ca n't even see balance . When payment due amount . Tried call number help unable speak staff . Always answered machine even I choose speak customer officer , also unable . Very bad service . label= 1
# {'neg': 0.078, 'neu': 0.783, 'pos': 0.138, 'compound': 0.3802} The reason I app ability generate tokens main page . Now hidden somewhere settings . Generating token takes lot longer getting SMS OTP . Since app n't serve purpose anymore , uninstalled 136MB ( ! ) freed . In addition , often welcome screen says login , fingerprint read , nothing happens . A step back reveals circle , circling forever . Have kill app restart work . label= 2
# {'neg': 0.119, 'neu': 0.807, 'pos': 0.074, 'compound': -0.4019} I 'd rather install new update given choice . The retardation new update frustrating . Tapping back arrow X ( close window ) either takes forever return n't work . I 've close app & login access home page coz 's quicker . Before update , app responsive ... , 's total drag . Customer service operators apparently equipped handle advanced questions pertaining app . The management blame . label= 2
# {'neg': 0.116, 'neu': 0.775, 'pos': 0.108, 'compound': -0.3707} The new updated app horrible . Loading times much slower sometimes I restart app check something . I 'm also unable delete office number without inputting fake 8-digit number . I also difficulty seeing 2nd text field onwards certain forms , even though I type fields . Ca n't see I 'm typing keyboard blocks fields page n't scroll downwards . My name also spelt wrongly app ; I ca n't edit . label= 2
# {'neg': 0.321, 'neu': 0.634, 'pos': 0.045, 'compound': -0.9456} Poor app , bad bank . Not app optimised Android ( unable navigate back ) , 's one worst banking apps I 've used I ca n't accurately see much I need pay cards . Multiple times I 'll paid amount shown app , receive emails saying I still owe couple dollars may charged interest . Overall poor experience I 'll cancel cards account soon . label= 1
# {'neg': 0.049, 'neu': 0.871, 'pos': 0.08, 'compound': 0.1531} 1 . It takes lot tapping get balance , I tap button scanning fingerprints/face Id ? 2 . UI overloaded unnecessary information / adverts , I ca n't see balance opening app 3 . After logging app keeps loading panels , view jerking seconds I actually anything useful 4 . There way rebating cash back app , I go messages send text magic words magic number . Embarrassing label= 2
# {'neg': 0.217, 'neu': 0.736, 'pos': 0.047, 'compound': -0.8588} This app horrible . Ca n't get information needed . Not easy navigate . And bank hotline forever busy , pick hang several times ! Very bad experience . This app n't really serve 's purpose . I wanted get touch clear 's anonymous charges keep incurring monthly . The app n't let type message label= 1
# {'neg': 0.214, 'neu': 0.628, 'pos': 0.158, 'compound': -0.6862} Not user friendly . When click get touch . It told contact Citi Phone banking . But number contact details appear . I navigate elsewhere search instead . So dumb . Also , I ca n't get much things done well like waiver . I still go phone line . Please enhance spare us agony wasting time contacting yr phone lines . label= 1
# {'neg': 0.104, 'neu': 0.839, 'pos': 0.057, 'compound': -0.2057} Ca n't access secure inbox mobile Scan QR work changing new phone despite signing Citi Mobile Token new device alterate way log secure inbox Scan QR works old phone n't let authenticate logging I never problem banks label= 1
# {'neg': 0.196, 'neu': 0.556, 'pos': 0.248, 'compound': 0.5302} Very good apps however payment transaction history quite misleading confusing . Transaction paid every detailed clear . Once click paid transaction shows pay points quite contradicting . Transaction history detailed , clear , precise simplified overall good apps . 👍👍 label= 2
# {'neg': 0.0, 'neu': 0.914, 'pos': 0.086, 'compound': 0.5562} Updated 4May : I written back customersvc mailbox screenshots attached . Pls look . Edited 3May : I made payment app linked account another bank . That account defo sufficiently funded . Why n't payment go ? And incurred late charge ! Goodness ... check check multiple times initiate transfer/payment bank 's app . Have go hassle requesting waiver late fee .. label= 1
# {'neg': 0.241, 'neu': 0.58, 'pos': 0.179, 'compound': -0.4952} I using new interface couple months really bad . Previously , easy tell much paid , due due - could glance . Now click click wait load . Its intuitive . Its difficult search statements well . Help . Want pay bills also difficult . Really tempted cancel card interface . label= 1
# {'neg': 0.102, 'neu': 0.756, 'pos': 0.142, 'compound': 0.34} I ca n't open app - unable proceed . Need developer options . As I need pay credit card bill . Please let IT developer include Phone model immediately without delays . Any late payment charges waived . label= 1
# {'neg': 0.33, 'neu': 0.67, 'pos': 0.0, 'compound': -0.7501} Poor , fee waiver ; require call hotline , hotline also handle request Sunday . That totally unacceptable nowadays . label= 1
# {'neg': 0.16, 'neu': 0.685, 'pos': 0.156, 'compound': -0.0516} This new version Citibank app failure . Google phone ( Model : Pixel 3 XL , Android version : 10 ) allowed log ( stayed circling blue-screen ) -- serious regression bug existed earlier versions -- poor interoperability . 0 star . I urge reinstate earlier version , please help fix asap . Thank . label= 1
# {'neg': 0.205, 'neu': 0.717, 'pos': 0.078, 'compound': -0.6209} It seems drain battery like crazy ! ! My phone used last whole day still left around 20 % , updating app , battery 3 % half day ! What heck new forced update ? ! label= 1
# {'neg': 0.15, 'neu': 0.806, 'pos': 0.044, 'compound': -0.6705} For two months I problems logging app , screen stuck spinning loading circle biometric authentication . Even password log I ca n't log app . I end try consecutive days I log cycle repeats . The app notifications also show promptly I 've transactions , showing dozens I managed log spamming phone outdated notifications . Please fix app . label= 1
# {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'compound': 0.6124} Been two week , I login application using fingerprint . Still waiting solution hopefully n't charge late payment due login issue label= 1
# {'neg': 0.079, 'neu': 0.676, 'pos': 0.244, 'compound': 0.6808} Your Citibank apps sometimes login got problem . Uninstall re-install Reset password try still login . Call help line support told try reset still unable login existing password . Thanks . label= 1
# {'neg': 0.224, 'neu': 0.712, 'pos': 0.064, 'compound': -0.6921} So many function leads system error proceed . Instructions dont match site well even send enquiry email lead error ...... No longer provide points breakdown .. points using Gpay , must use physical card , told customer support label= 1
# {'neg': 0.075, 'neu': 0.744, 'pos': 0.181, 'compound': 0.457} I ca n't open app expects read entire paragraph words ca n't ( developer settings ) like within seconds closes . Why app special I use bank apps easily label= 1
# {'neg': 0.407, 'neu': 0.593, 'pos': 0.0, 'compound': -0.8519} After updating app , log using fingerprint fails work . No use fanciful features log function fails poses much inconvenience user . label= 1
# {'neg': 0.186, 'neu': 0.731, 'pos': 0.083, 'compound': -0.8114} Please fix broken ! After update , generation mobile token obscured even , required logging . Additionally verification code generated even work ! On top get stuck generation verification code page without way go back . Over multiple versions app seems get worse . First login problems , fingerprint login work , verification code . It 's almost want users using app . label= 1
# {'neg': 0.149, 'neu': 0.615, 'pos': 0.236, 'compound': 0.8548} looks like citibank really trying hard avoid communicating customers . phone , email , account mail messages ca n't sent due `` illegal '' characters wo n't say ones illegal . And 's chat make wait hours someone get back n't reply message 2 minutes , get kicked queue BUT DO manage hold , customer support pretty good . CS good . Bank sucks label= 1
# {'neg': 0.202, 'neu': 0.663, 'pos': 0.135, 'compound': -0.6775} Worst application ever ! Now I 'm rethinking decisions getting credit card bank ! Even customer service n't help ! I proceeded download app followed steps creating account , however trying several times , mobile app response still `` ERROR '' . I follow username password criteria , sure 's working . label= 1
# {'neg': 0.073, 'neu': 0.769, 'pos': 0.158, 'compound': 0.6369} After paying credit card amount using app . The app `` hang '' progress status spinning non stop . Have prematurely exit app restart . This 2nd time I encountered . The happened last month I used pay first time . For security reason , I n't think I using app payment transactions . label= 1
# {'neg': 0.08, 'neu': 0.701, 'pos': 0.219, 'compound': 0.8207} Website says damsel card much app . So much services hidden . Just like frustrating hotline , repeating app great every option . And order reach cancel option 've already spent 10mins line waiting recording finish . App slow , responsive mainly n't show many banking needs . Totally customer oriented , cares users using cc putting money . label= 1
# {'neg': 0.143, 'neu': 0.857, 'pos': 0.0, 'compound': -0.6124} often app upgrade , display changes . unnecessary , user get used display ui , unfriendly keep changing unless really needed . Still find app unfriendly using awhile . xfer , info screen show , amount , rather amount , . sequence right . label= 2
# {'neg': 0.185, 'neu': 0.691, 'pos': 0.123, 'compound': -0.5719} App 1000 times better previously . Now takes either long load impossible use app . The enable magnetic strip overseas use useless . Still rely SMS sent payment authorization . Since I using another phone number overseas , I got cards blocked resort borrowing friends . Customer service hotline next useless unprofessional . Time change primary bank . label= 1
# {'neg': 0.193, 'neu': 0.728, 'pos': 0.079, 'compound': -0.743} When supply wrong pin code app , app still generates OTP , fake one let think everything working . At time locks Internet banking account . There indicates account locked call bank . What waste time . The app makes everything secure I longer want use . label= 1
# {'neg': 0.227, 'neu': 0.69, 'pos': 0.083, 'compound': -0.8199} The reviews affirmed frustration app I 'm alone . I using make monthly payments . Suddenly , function disappeared . I wasted several hours searching app without avail . For moment I thought I dementia . I googled find answers seemed nothing wrong . I eventually resorted Web browser version make payment I almost late . Other , I also angry 's way redeem cashback value . label= 1
# {'neg': 0.266, 'neu': 0.605, 'pos': 0.129, 'compound': -0.6887} Honestly , 's irritating go steps paying online hangs . Not , twice 3 times . I almost switched credit cards time look wallet . This app also difficult navigate . And make payment , give error message . Waste time . label= 1
# {'neg': 0.322, 'neu': 0.678, 'pos': 0.0, 'compound': -0.5849} App increasingly force user register finger print . Very bad . label= 1
# {'neg': 0.186, 'neu': 0.681, 'pos': 0.133, 'compound': -0.601} Three issues I noticed new update . One . After viewing monthly statement , back button home . Pressing phone 's back button also n't work . So 's stuck , view statements . Two . The app n't close ! No matter many times I press back button . Three . The important one - I ca n't pay credit card bill ready credit I funds inside . Ready credit displays funds negative sign . Therefore , says I insufficient funds . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Not working Google pixel 7 pro , n't even jailbreak root , apps keep shown I root jailbreak , I ca n't even check apps statement label= 1
# {'neg': 0.093, 'neu': 0.655, 'pos': 0.252, 'compound': 0.8404} recently added feature cashout cashback . recently send sms time , time would work sometime n't . great experience bank received award best banking app . I ca n't login sometimes `` 's unavailable '' , ca n't tell much I need pay credit card easily label= 2
# {'neg': 0.115, 'neu': 0.885, 'pos': 0.0, 'compound': -0.6705} I 'd rate zero Google allowed . Terrible experience ... I 've staring screen 5 mins looking indication much bill I ca n't find anything except cross selling bullshjt . Seriously . Did guys even test ? And 's weird icon supposedly balance amount ... What heck icon even mean . A square arrow pointing ... Even literally describing icon makes zero sense . label= 1
# {'neg': 0.0, 'neu': 0.759, 'pos': 0.241, 'compound': 0.9349} Amazing , 4 months nothing still done mobile app . The issue I raise last December 2019 still happening . I sent app developer email issue , please sort ASAP . In short , paying Card account , screen froze circular icon spinning . You sure payment successful . The last Dec , happen , I tried 3 times , ending paying $ 4K extra card . I guess Citibank earning interest .... label= 1
# {'neg': 0.147, 'neu': 0.743, 'pos': 0.109, 'compound': -0.5061} Horrible . So put device security reasons , becomes limited one device . If , send endless OTPs every single thinf want . If every OTP gets sent phone already know I get , additional security ? It bad back day every single layer people tou talk phone asks particulars till blue face , may may get see correct dept . label= 1
# {'neg': 0.121, 'neu': 0.763, 'pos': 0.115, 'compound': -0.3182} UX bad . Back button n't work , must tap top left back button top right X button , inconsistent unnecessary android already fixed back button . The consistent prompt advertise loan annoying . I looking statement bill could n't find hidden behind small blue window loan advertisement . Please something UX . label= 1
# {'neg': 0.285, 'neu': 0.677, 'pos': 0.038, 'compound': -0.9081} The chat function works sense staff reply fairly quickly , problem requires follow - staff n't update even whole day . Also app laggy sabotage users ; even simple exploration lag causes problems one end redeeming citi points accident . Abit slow n't use hurry . label= 2
# {'neg': 0.051, 'neu': 0.859, 'pos': 0.089, 'compound': 0.2714} ( 8/3 ) The updated app works . ( 10/2/23 ) Well , worked 1 day . Need reinstall work . ( 9/2/23 ) After 3 months , app finally fixed ! After reinstalling , 's working . ( 2/11/22 ) Like many others , I ca n't launch app updating . My phone rooted Magisk installed . Emailed customer service kept getting useless replies insist users getting message phones rooted Magisk . label= 4
# {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compound': -0.5106} today used App , told update . could n't update put button . uninstalled App , installed , failed three times . label= 1
# {'neg': 0.181, 'neu': 0.819, 'pos': 0.0, 'compound': -0.4767} Worse app activate card . If registered biometric , delete app install activate . Decided terminate citi cards . label= 1
# {'neg': 0.034, 'neu': 0.7, 'pos': 0.266, 'compound': 0.8816} Would like suggest app include functionality customers redeem cashback credit cards . If , least allow customers via WhatsApp messaging . Do n't limit SMS . Secondly , could secure messaging Citibank app . It would facilitate enquiry suggestions improve process . This feedback channel workaround . Thank . label= 4
# {'neg': 0.0, 'neu': 0.94, 'pos': 0.06, 'compound': 0.3612} It seems like developer half-assed copied design iOS without consideration Android UI works differently iOS . The Android back button n't even work app . And `` Place fingertip * home button * '' . Most android phones n't even fingerprint scanners home button years . label= 1
# {'neg': 0.241, 'neu': 0.69, 'pos': 0.069, 'compound': -0.6696} Continous unbelievable app failure authenticate access right , either token QR code ! I call customer service view e statement payment . The problem persists months label= 1
# {'neg': 0.147, 'neu': 0.853, 'pos': 0.0, 'compound': -0.4767} Terrible update , wrongly detected developer options . I enable developer option disable app work . Once works shows touch id working ... label= 1
# {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.4019} Scanning QR codes n't work . After authentication spins ages dumps back start screen . label= 1
# {'neg': 0.397, 'neu': 0.603, 'pos': 0.0, 'compound': -0.8197} Horrible App ! ! ! Out blue n't allow launch App saying detected phone Developer Options ... This ridiculous . label= 1
# {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'compound': 0.4404} Simple authorisation sms works much better push notifications . While trade authorisation claims need signing , clients still need provide password . How different signing ? label= 2
# {'neg': 0.086, 'neu': 0.914, 'pos': 0.0, 'compound': -0.2878} Very basic app limited options .... every minor thing call helpline RM . Ca n't open FD , new card account application point redemption options .. label= 1
# {'neg': 0.2, 'neu': 0.578, 'pos': 0.222, 'compound': 0.5293} new update disabled fingerprint scan unlock . n changed password . locked halfway . n unable log . ... definitely needs rectified . major annoyance shows security issues doubtful . Once problems successfully logged terms n conditions page . Agreed . N kicked . Umpteen times . Wow . Not sure want continue using card expiries I emailed ... 2 days ago . No reply since . label= 1
# {'neg': 0.316, 'neu': 0.561, 'pos': 0.122, 'compound': -0.5859} Lousy app . Pops security info close within seconds , Im even able read error message . label= 1
# {'neg': 0.129, 'neu': 0.539, 'pos': 0.332, 'compound': 0.5994} [ 2023-11-20 ] Which smart product manager thought disabling screenshots screen selection functions good feature ? It add anything security . label= 2
# {'neg': 0.195, 'neu': 0.805, 'pos': 0.0, 'compound': -0.6785} Could n't log via Citibank Mobile App Citibank Online 2 weeks . Keep calling citibank hotline nothing yet resolve . Very disappointed everytime I follow seem nothing getting fixed . label= 1
# {'neg': 0.215, 'neu': 0.785, 'pos': 0.0, 'compound': -0.6588} Worst banking app ever . So many bugs unable log repeatedly . Very slow loading speed . Do download app ! label= 1
# {'neg': 0.336, 'neu': 0.574, 'pos': 0.09, 'compound': -0.7906} Still issues uninstall reinstalling ... keeps detecting different devices , app getting worst worst ... working ok ... 😞 label= 1
# {'neg': 0.169, 'neu': 0.62, 'pos': 0.211, 'compound': 0.25} Recently , I keep problem opening app , keeps promoting try later😩 unable use credit card pay bills needs verify app ... label= 2
# {'neg': 0.132, 'neu': 0.685, 'pos': 0.183, 'compound': 0.0258} Connect us option n't work , stay respond . Frustrating want rectify situation & phone customer support officer pushed connect online label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Unable run log approve transactions . App says phone rooted 's . What 's point bank I ca n't approve transactions label= 1
# {'neg': 0.103, 'neu': 0.703, 'pos': 0.194, 'compound': 0.5248} Nicely designed , worked well several problems 1 . Does n't launch Android 10 2 . Loading icon n't stop spinning paying bills 3 . A totally different layout interface I click cards . It 's like 2 different apps one , confuses I click Payments main app versus Cards 'mini-app ' different experience label= 3
# {'neg': 0.206, 'neu': 0.515, 'pos': 0.278, 'compound': 0.34} I ca n't login app I existing customer wish cancel card . And wish login account cancel . label= 1
# {'neg': 0.049, 'neu': 0.865, 'pos': 0.086, 'compound': 0.3956} Does help . I asking abt waiver annual fees . No options . I call request waiver annual fees 2/3 weeks back . Till reply I charge finance fee . And I updayed new email address still notifications send old email address . Any Citi officers see massage . Reply soon possible ! ! ! ! ! ! ! label= 1
# {'neg': 0.115, 'neu': 0.791, 'pos': 0.094, 'compound': -0.2732} Ca n't even manage log . I remember frustrated Citibank experience I getting address changed getting different departments update particulars years back . I recently signed Citibank got credit card know . I ca n't even log app . The password I set n't work tries got locked . Tried reset password kept giving error message . label= 1
# {'neg': 0.173, 'neu': 0.729, 'pos': 0.098, 'compound': -0.5572} Very frustrating experience . Called hotline I option I need , option speak human either . Thinking I may heard well , I recalled hotline 3 times , re-listening taking 30minutes still leaving way resolve issue . All I wanted reactivate account given error message ibanking site , asking call hotline n't useful . label= 1
# {'neg': 0.13, 'neu': 0.62, 'pos': 0.25, 'compound': 0.8142} The App used work great since upgrade interface change I ca n't seem initiate payment credit card months . Keep getting error message . Called hotline enquire months back said pay credit card function ? It 's 3 months 's fixed ? ! ? Pretty much useless App . label= 1
# {'neg': 0.12, 'neu': 0.581, 'pos': 0.299, 'compound': 0.807} 1000 % better ! Was tempted leave Citi due previous horrific versions app , sorted basics ... done good job FINALLY . Frankly I n't patting back basic app works well ... far behind curve , I thought encouragement would useful 🤣 label= 5
# {'neg': 0.064, 'neu': 0.765, 'pos': 0.172, 'compound': 0.7579} Terrible app . Was use app pay credit card bills . But told update downloading app multiple times told unable install app . Uninstalled old Citi app reinstall - n't work . Restarted phone reinstall - n't work . But despite functioning app , I 'm sure bank continue charge interest fees anyway . label= 1
# {'neg': 0.204, 'neu': 0.666, 'pos': 0.13, 'compound': -0.6996} I rarely rate app , app number issues : ( 1 ) 30+ seconds load ! This ridiculous . There clearly dependencies skipped , like checking location ( 2 ) No error returned OTP pin incorrect . This lead account inactivation ( 3 ) Fingerprint often fails requiring entering pwd ( 4 ) Unable paste clipboard . Annoying entering account numbers , details . Should allow paste every entry fields used . Fix 4 issues , 5 star label= 1
# {'neg': 0.237, 'neu': 0.763, 'pos': 0.0, 'compound': -0.4767} able access app . keeps saying I Developer Options enabled wrong . I n't enabled . label= 1
# {'neg': 0.34, 'neu': 0.618, 'pos': 0.042, 'compound': -0.8793} This app lousy ! I ca n't get see anything ! Very angry I write . Ca n't give advice helps ! I wo n't know pay bills ! Get fix ! label= 1
# {'neg': 0.056, 'neu': 0.863, 'pos': 0.081, 'compound': 0.34} Update 17 Mar 2019 . Tried installing app . It n't even start . Clicking icon displays message , `` sorry , Citibank SG stopped . '' -- -- I 've installed month , never even seen login screen . Each time I click icon , message `` please wait seconds load '' , followed long time `` experiencing temporary delays , please try later . '' label= 1
# {'neg': 0.027, 'neu': 0.773, 'pos': 0.2, 'compound': 0.7655} One main things consumers look digital banking apps ability reach customer support conveniently , via live chat function mailbox app send enquiries get case support . It 's kinda silly Contact page directing users phone banking instead . Point consider UI/UX team . label= 2
# {'neg': 0.156, 'neu': 0.72, 'pos': 0.124, 'compound': -0.4401} I see numerous adverse reviews . Had install app activate credit card . Was prompted create login ID , led endless rejection attempted suggested login IDs . Gave trying 10th login ID rejected app . Fortunately , card got activated despite failed attempts getting login ID . This process used much simpler via SMS ... much convenient . label= 2
# {'neg': 0.223, 'neu': 0.641, 'pos': 0.137, 'compound': -0.7269} many complaints see 13 dec 2018 update .. experienced buggy interface .. uninstalled reinstalled .. app work . However 's bad enough existing app work updates done .. adds bad review uninstall reinstall app updates get work . hope improvements done eventually eliminate bad experience .. Thanks . label= 2
# {'neg': 0.132, 'neu': 0.697, 'pos': 0.172, 'compound': 0.6666} Received credit card statement . Login app see statement outstanding amount paid . Next day , verified statement balance $ 0 ( fully settled card bill ) . Went dinner evening swiped $ 40 . Next day statement outstanding balance show $ 40 due almost immediately . This seriously confusing misleading new transaction could added past statement , incur late charges fee I notice . label= 1
# {'neg': 0.265, 'neu': 0.601, 'pos': 0.134, 'compound': -0.8629} The app sucks badly . It takes forever app load login screen . And time app crash . When works embarrassingly slow need make transfer paynow . I saw alot remarks review people app blue screen waiting load . Why n't Citibank taking seriously ? Stop giving template reply customer email quote codes . Just admit problem address . Where service excellence ? ? Fix problem ! label= 1
# {'neg': 0.118, 'neu': 0.696, 'pos': 0.186, 'compound': 0.4936} Was fine till recently kept telling I Developer Settings enabled . After turning , n't allow use biometrics issues pw login . When going forget password process , mentions data found . Tried create new account , says I n't secure connection . Man , else I need ? Please resolve ASAP . label= 1
# {'neg': 0.252, 'neu': 0.703, 'pos': 0.045, 'compound': -0.8885} New interface mess . They lumped everything together give bill due date proper monthly statements . Looks like cynical disingenuous plan extract late charges customers . The 3 years ago 's gotten even worse update .. go lot see balance need OTP see bill . I 'd rate negative stars I could . label= 1
# {'neg': 0.063, 'neu': 0.797, 'pos': 0.139, 'compound': 0.296} Update 2 : The issue back `` advertorial '' banner back top . Update : The issue fixed removing `` advertorial '' banner top homepage page . Issue : At homepage , logging , Citibank App always auto-scoll back top scrolling up/down . Bad user experience . Please fix . Device : Samsung S21 Ultra debugging . Will remove review 's fixed . label= 1
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.9062} The app okay basic banking purposes . The first page bit laggy still better banks . But fee waiver using phone banking used much easier .. I tried calling , need key numerous verification end still need speak officer course pick still need wait called back ... Wow .. label= 3
# {'neg': 0.131, 'neu': 0.806, 'pos': 0.063, 'compound': -0.5719} 1 . Back button android n't work ie . ca n't go back previous page ( use back button provided app ) . 2 . Ca n't copy paste sms otp app . 3 . When try activate credit card , phishing warning message ( tell customer beware phishing attempt ) top screen blocks half page . I ca n't dismiss ca n't see beneath warning message ( need activate card ) . The warning message goes away sometime . Poorly tested . label= 2
# {'neg': 0.167, 'neu': 0.588, 'pos': 0.245, 'compound': 0.1531} Rewards points expiry without inform/shown latest statements , straight away deduct points , 2nd time happen , disgusting label= 1
# {'neg': 0.077, 'neu': 0.865, 'pos': 0.058, 'compound': -0.1531} App notifications crazy . It give 12 notifications day transactions happened yesterday 2 days ago . Tried logging see I mark notifications read n't able get . Edit : I uninstalled reinstalled app working fine since . label= 5
# {'neg': 0.052, 'neu': 0.789, 'pos': 0.159, 'compound': 0.5194} Whatever transaction I made , appear statement balance even though made billing cycle . It n't sync I n't want charge late interest payment app n't make sense . It wasnt like update . Statement balance sync pdf statement . Please fix glitch . label= 2
# {'neg': 0.081, 'neu': 0.919, 'pos': 0.0, 'compound': -0.4927} For weeks I tried update APP . After download refuses install properly . I called helpline advised delete reinstall whole thing . This I tried still install . I tried three separate Android phones , Samsung latest models . Absolutely frustrating means Mobile Token online banking work . label= 1
# {'neg': 0.0, 'neu': 0.425, 'pos': 0.575, 'compound': 0.9455} Very good could bit friendly seniors . However kudos citi reacting quickly query account . Very impressed . Many thanks . label= 4
# {'neg': 0.125, 'neu': 0.717, 'pos': 0.158, 'compound': 0.4215} There update enhance security online transactions . I followed instructions , rekeyed ID password , sms 2FA . Received notification successful , fingerprint login stopped working , prompted enrol `` new device enhanced security feature '' . Tried enrollment 4 times , still . No fingerprint login . Attempts manage fingerprint login within app resulted error message . label= 2
# {'neg': 0.328, 'neu': 0.48, 'pos': 0.192, 'compound': -0.6249} Painfully slow load use , huge memory hog well . The worst banking app I 've used date . label= 1
# {'neg': 0.169, 'neu': 0.688, 'pos': 0.144, 'compound': -0.1027} I always trouble accessing apps , always indicate available . Can IT quickly fixed issue please label= 1
# {'neg': 0.145, 'neu': 0.814, 'pos': 0.041, 'compound': -0.6597} This terrible app bank lowered service standards lot years . I tried amend personal details , trying get one time PIN via SMS able thus use app . There many examples well , unrelated app , Citi bank . I held account Citi last 20 years , service levels worsened progressively - especially last five years . label= 1
# {'neg': 0.225, 'neu': 0.596, 'pos': 0.179, 'compound': -0.6696} Seriously , whoever Product Manager App , fired . This critical reason I thinking canceling Citibank credit card . 1 . Sluggish user interface design . You scroll multiple times go . 2 . Useless ads New year etc . create issues handling . 3 . App interface Citibank site help content match . I searching tab exist App . For God 's sake , proper CI/CD pipeline documentation/help-content . If team technically competent , version management documentation least . 4 . I still ca n't figure cashback App ! Thanks poor interface , lack help content , poor navigation design . label= 1
# {'neg': 0.159, 'neu': 0.709, 'pos': 0.132, 'compound': -0.1801} Citibank n't interested providing customers good banking service . Notifications say transaction read customer app go app cryptic trying find info . Very poor , slow , expensive citi miles transfer credit card airline stop using citi visa card miles . Amex direct also transfer minutes another country amex . Citi interested profits providing basic banking functional service . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Can fix app ? Almost everytime I launch , said Developer Mode enabled disallow login . ( developer mode enabled ) label= 1
# {'neg': 0.18, 'neu': 0.642, 'pos': 0.178, 'compound': -0.024} The previous UI important information home screen easy access common functions like payment statements . This UI next useless prioritize trying get use new features/services hide common function behind layers menu . Extremely unfriendly . label= 1
# {'neg': 0.305, 'neu': 0.671, 'pos': 0.024, 'compound': -0.9386} It 's horrible BANKING apps ever . No contact number stated emergency note page stated emergencies . Trouble login , screen showed unable process , try later , day later , tried , still displayed window pop without help displayed get touch . Absolutely big failure apps ever coming international brand bank . label= 1
# {'neg': 0.069, 'neu': 0.76, 'pos': 0.171, 'compound': 0.5106} I use password management software . This app , reason refuses allow auto fill copy paste function password input despite banking app I 've used . This counter intuitive security perspective since I 'm inclined use password easy remember , short consequence , weak . label= 1
# {'neg': 0.134, 'neu': 0.662, 'pos': 0.204, 'compound': 0.5971} Very bad experience . Somehow PW entered always wrong , resetting PW also always issue . Everytime I needed enter app , I 100 % certain I able enter first try . Why app user friendly . Even I try call help line reset PW , brings one place another , 's inconvenient reset PW . After resetting PW , I still enter app . Oh goodness , please work user experience ! ! ! label= 1
# {'neg': 0.159, 'neu': 0.763, 'pos': 0.078, 'compound': -0.5983} For trouble logging Citi app , uninstall reinstall app fix problem . The issue first open app , 2 questions asked app allow access phone call location . If disallow access , ca n't get Home screen 2 questions asked , thus making app stuck limbo . Remember allow access prompted ! label= 4
# {'neg': 0.146, 'neu': 0.768, 'pos': 0.086, 'compound': -0.5413} Very annoying . Since apps updated months back , able login . Originally thought wrong password . Changed password , able login .. login days , able login saying incorrect password . Looking reviews , realised number experience . Dont even deserve star . Please fix . label= 1
# {'neg': 0.195, 'neu': 0.783, 'pos': 0.023, 'compound': -0.872} Finally ... login .. 17.7.19 16.7.19 : Terrible app . 1st time ever download app activate card . Followed instructions activate card , thereafter , received sms saying activated . However , unable login see anything kept getting error messages . Even keyed card number details clicked trouble logging , error message kept appearing . Nothing happened . Can login , work . label= 1
# {'neg': 0.071, 'neu': 0.791, 'pos': 0.138, 'compound': 0.3818} able log 4 weeks , app kept hanging blue citi screen could access account info . receive push messages regarding payment reminders purchases . get notifications reminders log app , like 30 notifications appear . useless app , sms notification better . label= 1
# {'neg': 0.112, 'neu': 0.609, 'pos': 0.279, 'compound': 0.5106} Phone # change - format unable correct . No easy instruction find notify credit card transactions via sms . label= 2
# ...
# {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.296} Ok could.not find cashback amount label= 4
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} CA N'T activate sub card label= 1
# {'neg': 0.361, 'neu': 0.309, 'pos': 0.33, 'compound': -0.0772} Bad experience .. friendly user label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Ca n't run app . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} This APP response sometime . label= 3
# {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404} easy use label= 5
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} What happen citi app ? Ca n't open label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Can I 2 separate accounts onto app label= 5
# {'neg': 0.0, 'neu': 0.365, 'pos': 0.635, 'compound': 0.539} Very user friendly label= 5
# {'neg': 0.0, 'neu': 0.238, 'pos': 0.762, 'compound': 0.4939} user friendly . label= 1
# {'neg': 0.0, 'neu': 0.238, 'pos': 0.762, 'compound': 0.4939} user friendly . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} keeps shutting ! ! ! label= 1
# {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404} Easy n convenient label= 5
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} wont even open , ca n't bank online label= 1
# {'neg': 0.412, 'neu': 0.588, 'pos': 0.0, 'compound': -0.5423} Presentation accounts lousy . Figures n't tally . label= 2
# {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404} easy use label= 5
# {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.6369} Best Banking App far . label= 5
# {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404} easy use label= 5
# {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'compound': -0.0572} I cant get want see .. e-statement label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} How access I even register new user . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Ca n't email send message label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Kept hang . Can transfer label= 1
# {'neg': 0.239, 'neu': 0.761, 'pos': 0.0, 'compound': -0.296} No idea 's purpose app I ca n't much . label= 1
# {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'compound': 0.3384} Works quite well label= 5
# {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404} easy use label= 5
# {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215} easier use . label= 4
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Ca n't even login anymore label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Can redeem cash back via mobile apps label= 3
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Should tap annual fees wavie . label= 3
# {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404} easy use label= 4
# {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.4404} Makes life easy transfers payments couch . label= 5
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Ca n't even manage log . label= 1
# {'neg': 0.508, 'neu': 0.492, 'pos': 0.0, 'compound': -0.4767} It work . Fake app ? label= 1
# {'neg': 0.431, 'neu': 0.569, 'pos': 0.0, 'compound': -0.5849} So bad . Ca n't even log . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} icon small label= 4
# {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'compound': 0.3612} Ease & simple label= 5
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Can never find options claim cash back 😑 label= 1
# {'neg': 0.0, 'neu': 0.238, 'pos': 0.762, 'compound': 0.4939} user friendly label= 2
# {'neg': 0.714, 'neu': 0.286, 'pos': 0.0, 'compound': -0.3612} difficult use label= 1
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404} Good experience . Simple use . label= 5
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} waiver option app label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Never explain anywhere use functions app . label= 1
# {'neg': 0.551, 'neu': 0.449, 'pos': 0.0, 'compound': -0.5994} bad .. setting always got screw label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} There feedback column cases stated . label= 3
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Can find inbox label= 1
# {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'compound': 0.8008} VERY MUCH HAPPY ON THIS APP . USER FRIENDLY label= 5
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} OTP working label= 1
# {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.6124} like banks send sms remind ready statement payment label= 4
# {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.3818} Can find waive credit card annual fees label= 1
# {'neg': 0.568, 'neu': 0.432, 'pos': 0.0, 'compound': -0.3875} Not user friendly . label= 1
# {'neg': 0.538, 'neu': 0.462, 'pos': 0.0, 'compound': -0.5413} new update really disappointing label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Can log label= 1
# {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.0772} I want ask waiver annual fee , I contact label= 1
# {'neg': 0.0, 'neu': 0.12, 'pos': 0.88, 'compound': 0.8074} User friendly great label= 5
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} How come n't forgot user I 'd . Only forgot password label= 1
# {'neg': 0.123, 'neu': 0.877, 'pos': 0.0, 'compound': -0.1027} I n't even know much I 'm billed . How I supposed pay card bill ? label= 1
# {'neg': 0.0, 'neu': 0.147, 'pos': 0.853, 'compound': 0.7003} Good easy use label= 5
# {'neg': 0.193, 'neu': 0.614, 'pos': 0.193, 'compound': 0.0} Missed statement way new statement replace older statement . Gg label= 1
# {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404} easy use label= 5
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Slow download : ) label= 1
# {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.6808} Gd morning , pl kindly advise sms , cash back amount deduct billing last two mth , many thks label= 5
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Why u need access phone calls ? label= 1
# {'neg': 0.355, 'neu': 0.645, 'pos': 0.0, 'compound': -0.296} No function infor contacting citibank label= 2
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Nowhere check bank card balance . label= 1
# {'neg': 0.0, 'neu': 0.147, 'pos': 0.853, 'compound': 0.7003} Good n easy use label= 4
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Takes 1 min get main screen label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} activate replacement card working label= 1
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249} worst banking system loan shark standard . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} ca n't find activate new card ! label= 1
# {'neg': 0.369, 'neu': 0.631, 'pos': 0.0, 'compound': -0.6249} keep making reset password . worst bank app ever label= 1
# {'neg': 0.362, 'neu': 0.638, 'pos': 0.0, 'compound': -0.5267} Stupid decision , I must need SMS login ... label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} cant stock trading . convenient . label= 5
# {'neg': 0.697, 'neu': 0.303, 'pos': 0.0, 'compound': -0.3182} faulty time label= 1
# {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.6124} I computer literate . Please get one help log label= 1
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249} Worst . App . And . Banking . Experience . EVER . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Unable download statement label= 2
# {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.6808} Nice use app nice label= 5
# {'neg': 0.412, 'neu': 0.588, 'pos': 0.0, 'compound': -0.1027} A bit hard understand label= 3
# {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404} Better older version . label= 3
# {'neg': 0.403, 'neu': 0.597, 'pos': 0.0, 'compound': -0.4019} insane app many many update label= 1
# {'neg': 0.0, 'neu': 0.238, 'pos': 0.762, 'compound': 0.4939} user friendly label= 1
# {'neg': 0.403, 'neu': 0.597, 'pos': 0.0, 'compound': -0.4019} Wasting time . Ca n't log . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} I ca n't find payment due date information . label= 3
# {'neg': 0.0, 'neu': 0.147, 'pos': 0.853, 'compound': 0.7003} good easy use label= 4
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Not working past 2 3 weeks . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Can log label= 1
# {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6249} Great app banking label= 5
# {'neg': 0.523, 'neu': 0.27, 'pos': 0.207, 'compound': -0.5423} Error : Something went wrong . Please try . label= 1
# {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.0772} Makes location access mandatory . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Can even complete activating card label= 1
# {'neg': 0.259, 'neu': 0.494, 'pos': 0.247, 'compound': -0.033} Not iser friendly banks like dbs ' app label= 1
# {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.5826} I , even see credit line acct number . How make payment ! ! ! ? label= 2
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} ca n't log ! label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} There 's room request PW reset . label= 1
# {'neg': 0.568, 'neu': 0.432, 'pos': 0.0, 'compound': -0.3875} Not user friendly . label= 1
# {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'compound': 0.4215} I want try , Thank .. label= 3
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Token OTP TAC unable login citibank online change mailing address label= 2
# {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404} easy use . label= 5
# {'neg': 0.636, 'neu': 0.364, 'pos': 0.0, 'compound': -0.5423} Bad user interface label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} always provide prioritise customer first . label= 5
# {'neg': 0.7, 'neu': 0.3, 'pos': 0.0, 'compound': -0.3252} Not helpful . label= 1
# {'neg': 0.0, 'neu': 0.238, 'pos': 0.762, 'compound': 0.4939} user friendly label= 1
# {'neg': 0.636, 'neu': 0.364, 'pos': 0.0, 'compound': -0.5423} Hot line bad . label= 1
# {'neg': 0.467, 'neu': 0.533, 'pos': 0.0, 'compound': -0.3875} Not friendly user App label= 3
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Could start label= 3
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Can get otp transactions label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Can find services announced citi label= 1
# {'neg': 0.0, 'neu': 0.704, 'pos': 0.296, 'compound': 0.2732} otp app accepted locks online account label= 2
# {'neg': 0.353, 'neu': 0.647, 'pos': 0.0, 'compound': -0.2924} Ca n't activate credit card label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} payment gateway keeps hanging label= 1
# {'neg': 0.259, 'neu': 0.741, 'pos': 0.0, 'compound': -0.1027} Did remove scan pay app ? label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Where I download app Huawei Mate 30 phone ? label= 1
# {'neg': 0.568, 'neu': 0.432, 'pos': 0.0, 'compound': -0.3875} Not user friendly . label= 1
# {'neg': 0.568, 'neu': 0.432, 'pos': 0.0, 'compound': -0.3875} Not user friendly . label= 2
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} login label= 1
# {'neg': 0.636, 'neu': 0.364, 'pos': 0.0, 'compound': -0.5423} Bad . Very buggy label= 1
# {'neg': 0.568, 'neu': 0.432, 'pos': 0.0, 'compound': -0.3875} Not user friendly . label= 1
# {'neg': 0.5, 'neu': 0.5, 'pos': 0.0, 'compound': -0.4588} Awful customer service accessibility label= 1
# {'neg': 0.383, 'neu': 0.617, 'pos': 0.0, 'compound': -0.4767} Not able find app worse this🤮😵 label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} I cant download new update label= 2
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Hang try download app label= 1
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249} The worst mobile banking app I used label= 1
# {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404} easy use . label= 5
# {'neg': 0.594, 'neu': 0.406, 'pos': 0.0, 'compound': -0.6588} Worst app I used date ! label= 1
# {'neg': 0.445, 'neu': 0.555, 'pos': 0.0, 'compound': -0.3412} Not good enough Citibank label= 3
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Hv trying log last hour label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} ur app open . label= 1
# {'neg': 0.6, 'neu': 0.4, 'pos': 0.0, 'compound': -0.4588} unnecessary forced upon label= 2
# {'neg': 0.0, 'neu': 0.575, 'pos': 0.425, 'compound': 0.5719} Can find catalog redeem reward points label= 2
# {'neg': 0.0, 'neu': 0.238, 'pos': 0.762, 'compound': 0.4939} user friendly label= 2
# {'neg': 0.607, 'neu': 0.393, 'pos': 0.0, 'compound': -0.4754} Totally useless app . label= 1
# {'neg': 0.355, 'neu': 0.645, 'pos': 0.0, 'compound': -0.296} Where deactivate card ? I suspect compromised label= 1
# {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.75} V. Easy use . V. User friendly ! label= 5
# {'neg': 0.0, 'neu': 0.536, 'pos': 0.464, 'compound': 0.3818} Can activate credit card label= 1
# {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6249} Great App experience label= 5
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Unable install label= 2
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} I cant even open app label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} I ca n't even longin & suppose activate card ? ? ? label= 1
# {'neg': 0.394, 'neu': 0.606, 'pos': 0.0, 'compound': -0.3818} Advertisment blocking account view selection label= 1
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5994} No problems 👍 label= 4
# {'neg': 0.558, 'neu': 0.442, 'pos': 0.0, 'compound': -0.5849} Very bad developed apps label= 1
# {'neg': 0.234, 'neu': 0.766, 'pos': 0.0, 'compound': -0.0572} Ca n't find service I want label= 1
# {'neg': 0.534, 'neu': 0.466, 'pos': 0.0, 'compound': -0.5319} Could start . S06L ERROR label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} working Android Q label= 1
# {'neg': 0.25, 'neu': 0.75, 'pos': 0.0, 'compound': -0.1695} ca n't allow waive membership fee . label= 3
# {'neg': 0.504, 'neu': 0.496, 'pos': 0.0, 'compound': -0.7269} Worse app .. Ever . Was forced give 1 star label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Ca n't even update anymore label= 1
# {'neg': 0.403, 'neu': 0.597, 'pos': 0.0, 'compound': -0.4019} mobile token gives alot problem label= 1
# {'neg': 0.0, 'neu': 0.278, 'pos': 0.722, 'compound': 0.3818} Instructions clear . label= 3
# {'neg': 0.419, 'neu': 0.405, 'pos': 0.176, 'compound': -0.4215} Terrible . Pls provide paper statement . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Pr40pro able download app ! label= 1
# {'neg': 0.202, 'neu': 0.484, 'pos': 0.315, 'compound': 0.2344} Cant even allow register credit card label= 1
# {'neg': 0.568, 'neu': 0.432, 'pos': 0.0, 'compound': -0.3875} Not friendly user label= 1
# {'neg': 0.384, 'neu': 0.616, 'pos': 0.0, 'compound': -0.5766} FORCED users use app phasing mobile site label= 1
# {'neg': 0.508, 'neu': 0.492, 'pos': 0.0, 'compound': -0.4767} Biometric working 's wrong label= 1
# {'neg': 0.487, 'neu': 0.513, 'pos': 0.0, 'compound': -0.2263} Slow confusing uiux label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Ca n't open label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} Takes long update ! ! ! label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} I ca n't login time . label= 4
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} All app nothing . label= 1
# {'neg': 0.239, 'neu': 0.761, 'pos': 0.0, 'compound': -0.296} No telephone contact . email address similar web version label= 1
# {'neg': 0.0, 'neu': 0.238, 'pos': 0.762, 'compound': 0.4939} users friendly label= 2
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} finger print sensor ? label= 1
# {'neg': 0.607, 'neu': 0.393, 'pos': 0.0, 'compound': -0.4754} Totally useless app . label= 1
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0} A handy app . label= 5
# '\npos 是积极情感的分数。\nneg 是消极情感的分数。\nneu 是中性情感的分数\ncompound 是一个综合分数，它表示文本的整体情感倾向。这个分数是一个介于 -1.0 和 1.0 之间的浮点数，其中：\n\n\ncompound = ((pos-neu)-(neg-neu))/(pos+neu-neg)\n\n分数接近 1.0 表示文本具有非常积极的情感。\n分数接近 0.0 表示文本是中性的，没有明显的积极或消极情感。\n分数接近 -1.0 表示文本具有非常消极的情感。\n\n'
